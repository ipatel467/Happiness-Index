# %%
# Import Needed Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Import Datasets
df15_original = pd.read_csv('2015.csv')
df16_original = pd.read_csv('2016.csv')
df17_original = pd.read_csv('2017.csv')
df18_original = pd.read_csv('2018.csv')
df19_original = pd.read_csv('2019.csv')

# %%
# Create copies of dataset.
# Dont touch the original. We will work on the copy

df15 = df15_original.copy()
df16 = df16_original.copy()
df17 = df17_original.copy()
df18 = df18_original.copy()
df19 = df19_original.copy()

# %%
df18.head()
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.632           1.305           1.592
# 1             2            Norway  7.594           1.456           1.582
# 2             3           Denmark  7.555           1.351           1.590
# 3             4           Iceland  7.495           1.343           1.644
# 4             5       Switzerland  7.487           1.420           1.549
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.874                         0.681       0.202
# 1                    0.861                         0.686       0.286
# 2                    0.868                         0.683       0.284
# 3                    0.914                         0.677       0.353
# 4                    0.927                         0.660       0.256
#
#    Perceptions of corruption
# 0                      0.393
# 1                      0.340
# 2                      0.408
# 3                      0.138
# 4                      0.357

# %%
# We will look at the year 2019 for now

# %%
df19.head()
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.769           1.340           1.587
# 1             2           Denmark  7.600           1.383           1.573
# 2             3            Norway  7.554           1.488           1.582
# 3             4           Iceland  7.494           1.380           1.624
# 4             5       Netherlands  7.488           1.396           1.522
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.986                         0.596       0.153
# 1                    0.996                         0.592       0.252
# 2                    1.028                         0.603       0.271
# 3                    1.026                         0.591       0.354
# 4                    0.999                         0.557       0.322
#
#    Perceptions of corruption
# 0                      0.393
# 1                      0.410
# 2                      0.341
# 3                      0.118
# 4                      0.298

# %%
df19.describe()
# Out:
#        Overall rank       Score  GDP per capita  Social support  \
# count    156.000000  156.000000      156.000000      156.000000
# mean      78.500000    5.407096        0.905147        1.208814
# std       45.177428    1.113120        0.398389        0.299191
# min        1.000000    2.853000        0.000000        0.000000
# 25%       39.750000    4.544500        0.602750        1.055750
# 50%       78.500000    5.379500        0.960000        1.271500
# 75%      117.250000    6.184500        1.232500        1.452500
# max      156.000000    7.769000        1.684000        1.624000
#
#        Healthy life expectancy  Freedom to make life choices  Generosity  \
# count               156.000000                    156.000000  156.000000
# mean                  0.725244                      0.392571    0.184846
# std                   0.242124                      0.143289    0.095254
# min                   0.000000                      0.000000    0.000000
# 25%                   0.547750                      0.308000    0.108750
# 50%                   0.789000                      0.417000    0.177500
# 75%                   0.881750                      0.507250    0.248250
# max                   1.141000                      0.631000    0.566000
#
#        Perceptions of corruption
# count                 156.000000
# mean                    0.110603
# std                     0.094538
# min                     0.000000
# 25%                     0.047000
# 50%                     0.085500
# 75%                     0.141250
# max                     0.453000

# %%
df15.dtypes
# Out:
# Country                           object
# Region                            object
# Happiness Rank                     int64
# Happiness Score                  float64
# Standard Error                   float64
# Economy (GDP per Capita)         float64
# Family                           float64
# Health (Life Expectancy)         float64
# Freedom                          float64
# Trust (Government Corruption)    float64
# Generosity                       float64
# Dystopia Residual                float64
# dtype: object

# %%
df15['Happiness Score'].hist()
plt.title('Score Distribution');

# %%
df19['Social support'].hist();
plt.title('Social Support Distribtion');

# %%
df19['Freedom to make life choices'].hist()
plt.title('Freedom to make life choices');

# %%
df15['Freedom'].hist()
plt.title('Freedom to make life choices');

# %%
df19['GDP per capita'].hist()  
plt.title('GDP per Capita');

# %%
df15['Economy (GDP per Capita)'].hist()  
plt.title('GDP per Capita');

# %%
df19['Perceptions of corruption'].hist()  
plt.title('Perceptions of corruption');

# %%
df19.columns
# Out:
# Index(['Overall rank', 'Country or region', 'Score', 'GDP per capita',
#        'Social support', 'Healthy life expectancy',
#        'Freedom to make life choices', 'Generosity',
#        'Perceptions of corruption'],
#       dtype='object')

# %%
df19['Healthy life expectancy'].hist()  
plt.title('Healthy life expectancy');

# %%
df19['Generosity'].hist()
plt.title('Generosity');

# %%
df19.shape
# Out:
# (156, 9)

# %%
df15.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
# 3         0.03880                   1.45900  1.33095
# 4         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# 2                   0.87464  0.64938                        0.48357
# 3                   0.88521  0.66973                        0.36503
# 4                   0.90563  0.63297                        0.32957
#
#    Generosity  Dystopia Residual
# 0     0.29678            2.51738
# 1     0.43630            2.70201
# 2     0.34139            2.49204
# 3     0.34699            2.46531
# 4     0.45811            2.45176

# %%
df15.shape
# Out:
# (158, 12)

# %%
df15['Standard Error'].hist()

# %%
df15['Country'].nunique()
# Out:
# 158

# %%
df15['Region'].nunique()
# Out:
# 10

# %%
df15['Region'].unique()
# Out:
# array(['Western Europe', 'North America', 'Australia and New Zealand',
#        'Middle East and Northern Africa', 'Latin America and Caribbean',
#        'Southeastern Asia', 'Central and Eastern Europe', 'Eastern Asia',
#        'Sub-Saharan Africa', 'Southern Asia'], dtype=object)

# %%
df15.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
# 3         0.03880                   1.45900  1.33095
# 4         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# 2                   0.87464  0.64938                        0.48357
# 3                   0.88521  0.66973                        0.36503
# 4                   0.90563  0.63297                        0.32957
#
#    Generosity  Dystopia Residual
# 0     0.29678            2.51738
# 1     0.43630            2.70201
# 2     0.34139            2.49204
# 3     0.34699            2.46531
# 4     0.45811            2.45176

# %%
df15_grouped_happiness = df15.groupby('Region').agg({'Happiness Rank':'mean'}).reset_index()
df15_grouped_happiness.sort_values(by = 'Happiness Rank', ascending = True, inplace=True)

# %%
sns.barplot(data=df15_grouped_happiness, x='Region', y='Happiness Rank',palette = 'mako')
plt.xticks(rotation=90);
plt.title('Average Happiness Rank by Region');

# %%
df15_grouped_happiness_score = df15.groupby('Region').agg({'Happiness Score':'mean'}).reset_index()
df15_grouped_happiness_score.sort_values(by = 'Happiness Score', ascending = False, inplace=True)

# %%
sns.barplot(data=df15_grouped_happiness_score, x='Region', y='Happiness Score',palette = 'mako')
plt.xticks(rotation=90);
plt.title('Average Happiness Score by Region');

# %%
df15_grouped = df15.groupby('Region').agg({'Economy (GDP per Capita)':'mean'}).reset_index()

# %%
df15_grouped.columns
# Out:
# Index(['Region', 'Economy (GDP per Capita)'], dtype='object')

# %%
df15_grouped.rename({'Economy (GDP per Capita)':'Economy'},axis=1, inplace=True)

# %%
df15_grouped.sort_values(by = 'Economy', ascending = False, inplace=True)

# %%
sns.barplot(data=df15_grouped, x='Region', y='Economy',color = 'green')
plt.xticks(rotation=90);
plt.title('Average Economy by Region');

# %%
df15_grouped_corruption = df15.groupby('Region').agg({'Trust (Government Corruption)':'mean'}).reset_index()

# %%
df15_grouped_corruption.sort_values(by = 'Trust (Government Corruption)', ascending = False, inplace=True)

# %%
df15_grouped_corruption.rename({'Trust (Government Corruption)':'Corruption'},axis=1, inplace=True)

# %%
sns.barplot(data=df15_grouped_corruption, x='Region', y='Corruption', palette = 'rocket')
plt.xticks(rotation=90);
plt.title('Average Corruption by Region');

# %%
df15_grouped_freedom = df15.groupby('Region').agg({'Freedom':'mean'}).reset_index()

# %%
df15_grouped_freedom.sort_values(by = 'Freedom', ascending = False, inplace=True)

# %%
sns.barplot(data=df15_grouped_freedom, x='Region', y='Freedom', palette = 'mako')
plt.xticks(rotation=90);
plt.title('Average Freedom by Region');

# %%
df15_grouped_generosity = df15.groupby('Region').agg({'Generosity':'mean'}).reset_index()

# %%
df15_grouped_generosity.sort_values(by = 'Generosity', ascending = False, inplace=True)

# %%
sns.barplot(data=df15_grouped_generosity, x='Region', y='Generosity', palette = 'mako')
plt.xticks(rotation=90);
plt.title('Average Generosity by Region');

# %%
df15_grouped_life = df15.groupby('Region').agg({'Health (Life Expectancy)':'mean'}).reset_index()

# %%
df15_grouped_life.sort_values(by = 'Health (Life Expectancy)', ascending = False, inplace=True)

# %%
sns.barplot(data=df15_grouped_life, x='Region', y='Health (Life Expectancy)', palette = 'rocket')
plt.xticks(rotation=90);
plt.title('Average Health (Life Expectancy) by Region');

# %%
df15_grouped_dys = df15.groupby('Region').agg({'Dystopia Residual':'mean'}).reset_index()

# %%
df15_grouped_dys.sort_values(by = 'Dystopia Residual', ascending = False, inplace=True)

# %%
sns.barplot(data=df15_grouped_dys, x='Region', y='Dystopia Residual', palette='mako')
plt.xticks(rotation=90);
plt.title('Average Dystopia Residual by Region');

# %%
df15_grouped_se = df15.groupby('Region').agg({'Standard Error':'mean'}).reset_index()

# %%
df15_grouped_se.sort_values(by = 'Standard Error', ascending = False, inplace=True)

# %%
sns.barplot(data=df15_grouped_se, x='Region', y='Standard Error', palette = 'mako')
plt.xticks(rotation=90);
plt.title('Average Standard Error by Region');

# %%
sns.scatterplot(data = df15, y ='Happiness Score' , x = 'Economy (GDP per Capita)')
plt.title('Happiness and GDP');

# %%
sns.lmplot(data = df15, y ='Happiness Score' , x = 'Economy (GDP per Capita)')
plt.title('Happiness and GDP');

# %%
sns.scatterplot(data = df15, x = 'Freedom', y ='Happiness Score' )
plt.title('Happiness and Freedom');

# %%
sns.scatterplot(data = df15, x = 'Family', y ='Happiness Score' )
plt.title('Happiness and Family');

# %%
sns.scatterplot(data = df15, x = 'Generosity', y ='Happiness Score' )
plt.title('Happiness and Generosity');

# %%
sns.scatterplot(data = df15, x = 'Trust (Government Corruption)', y ='Happiness Score' )
plt.title('Happiness and Trust');

# %%
sns.scatterplot(data = df15, x = 'Health (Life Expectancy)', y ='Happiness Score' )
plt.title('Happiness and Health');

# %%
sns.scatterplot(data = df15, x = 'Dystopia Residual', y ='Happiness Score', hue = 'Region')
plt.title('Happiness and Dystopia Residual');
plt.legend(bbox_to_anchor=(1.05, 1.0), loc='upper left');

# %%
df15_grouped_happ = df15.groupby('Region').agg({'Happiness Score':'mean'}).reset_index()

# %%
df15_grouped_happ.sort_values(by = 'Happiness Score', ascending = False, inplace=True)

# %%
df15_grouped_happ
# Out:
#                             Region  Happiness Score
# 0        Australia and New Zealand         7.285000
# 5                    North America         7.273000
# 9                   Western Europe         6.689619
# 3      Latin America and Caribbean         6.144682
# 2                     Eastern Asia         5.626167
# 4  Middle East and Northern Africa         5.406900
# 1       Central and Eastern Europe         5.332931
# 6                Southeastern Asia         5.317444
# 7                    Southern Asia         4.580857
# 8               Sub-Saharan Africa         4.202800

# %%
sns.scatterplot(data = df15, x = 'Standard Error', y ='Happiness Score' )
